# %% [markdown]
# # (Google Play Store)
# ## by (Fahad Alnuaimi)

# %% [markdown]
# ## Investigation Overview
#
#
# > This presentation will illustrate the relationships between columns in Dataset Google play store to expline the distibution fo Data and what's the observation that have been built on these relations. The Visualization of Data will show how each variable intract with other and measure the effect over the outcomes.
#
# ## Dataset Overview
#
# > The Dataset is for Google play store which isthe main market for Android (Mobile opreating system), the Dataset contain 10841 rows and 13 columns. It has columnss aof app name, rating number, category of the app, content rating and how many got reviews and installs for each app.

# %%
# import all packages and set plots to be embedded inline
import numpy as np
import pandas as pd
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from pylab import rcParams
from plotly import __version__
# %matplotlib inline
import cufflinks as cf
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)

init_notebook_mode(connected=True)
cf.go_offline()
# suppress warnings from final output
import warnings
warnings.simplefilter("ignore")
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# load in the dataset into a pandas dataframe
df_play_store_clean = pd.read_csv('df_play_store_clean.csv')

# %% [markdown]
# > Note that the above cells have been set as "Skip"-type slides. That means
# that when the notebook is rendered as http slides, those cells won't show up.

# %% [markdown]
# ## Distribution of APPS Rating
#
# >Histogram represent data distribution, it can visulize larg amount of data and show how data behaive. From The distribution you can observe that data is normal distribution but the mean looks high which is 4.1 that means users have ratied high rating numbers of apps.

# %%
# rating distibution 
rcParams['figure.figsize'] = 12,10
g = sns.kdeplot(df_play_store_clean.rating, color="Blue", shade = True)
g.set_xlabel("rating")
g.set_ylabel("frequency")
plt.title('Distribution of APPS Rating',size = 20)

# drow red line for the mean 
plt.axvline(df_play_store_clean.rating.mean(), color='Red', linestyle='solid', linewidth=1)

# %% [markdown]
# ## Count Apps Type
#
# > Count the type of Apps, wether this app is free or paied. By counting the apps its hsow that 92% of apps are free and 8% are paied.

# %%
# code for the pie chart seen above
plt.figure(0,figsize = (6,7))
sorted_counts = df_play_store_clean['type'].value_counts()
plt.pie(sorted_counts, labels = sorted_counts.index, startangle = 90, counterclock = False, autopct='%1.0f%%');
plt.title('Count Apps Type',color = 'Black',fontsize = 15)
plt.show;

# %% [markdown]
# ## Bar Char Count Of Apps In Each Genres
#
# > Count the main genres of apps, the plot show that tools show the highst count of apps genres, then entertaimnet, education, busness and medical. This column have taken from column genres and splitted to two categories main and sub genres and this plot of main genres.
#
# - Tools
# - Entertainment
# - Education
# - Business
# - Medical

# %%
#prepare value count for plot
genres_counts = df_play_store_clean['m_genres'].value_counts()
genres_order = genres_counts.index
# visulizae main category 
plt.figure(figsize=(12,9))
plt.title('Count Of App In Each Genres',size = 20)
base_color = sns.color_palette()[4]
fig = sns.countplot(x=df_play_store_clean['m_genres'], color=base_color, order= genres_order)
fig.set_xticklabels(fig.get_xticklabels(), rotation=90)
plt.show(fig)

# %% [markdown]
# ## Category Rating rlationship with Reviews distributeed on it
#
# > The purpose of this visualization is to see user behavier on reviews, the four stars category has the highest reviews and most of review are bellow 10 millions

# %%
px.scatter(df_play_store_clean, width=600, height=600 ,x="rating_category",y="reviews", orientation="h", title="Category Rating rlationship with Reviews distributeed on it")
# Out:
# <div>
#
#
#             <div id="3eca3e39-dfd9-4207-95e3-1cfb170b7718" class="plotly-graph-div" style="height:600px; width:600px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("3eca3e39-dfd9-4207-95e3-1cfb170b7718")) {
#                     Plotly.newPlot(
#                         '3eca3e39-dfd9-4207-95e3-1cfb170b7718',
#                         [{"hovertemplate": "rating_category=%{x}<br>reviews=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "", "showlegend": false, "type": "scattergl", "x": ["four_stars", "three_stars", "five_stars", "four_stars", "four_stars", "four_stars", "three_stars", "four_stars", "four_stars", "five_stars", "four_stars", "four_stars", "four_stars", "five_stars", "four_stars", "two_stars", "five_stars", "four_stars", "four_stars", "five_stars", "three_stars", "four_stars", "five_stars", null, "five_stars", "five_stars", "five_stars", "four_stars", "three_stars", "four_stars", "four_stars", "four_stars", "four_stars", "four_stars", "five_stars", "three_stars", "five_stars", "four_stars", "five_stars", "three_stars", "four_stars", "four_stars", "four_stars", "three_stars", "four_stars", "five_stars", "five_stars", "four_stars", "four_stars", "four_stars", "three_stars", "three_stars", "five_stars", "three_stars", "four_stars", "five_stars", "four_stars", "four_stars", "three_stars", "three_stars", "five_stars", "five_stars", "four_stars", "five_stars", "five_stars", "three_stars", "three_stars", "four_stars", "three_stars", "four_stars", "five_stars", "three_stars", "four_stars", "five_stars", "five_stars", "five_stars", "four_stars", "four_stars", "four_stars", "five_stars", "three_stars", "four_stars", "three_stars", "four_stars", "three_stars", "four_stars", "four_stars", "two_stars", "five_stars", "five_stars", "four_stars", "three_stars", "five_stars", "five_stars", "five_stars", "three_stars", "four_stars", "three_stars", "five_stars", "five_stars", "five_stars", "three_stars", "three_stars", "four_stars", "five_stars", "four_stars", "five_stars", "five_stars", "five_stars", "four_stars", "four_stars", "four_stars", "four_stars", null, "four_stars", "four_stars", "four_stars", "three_stars", "four_stars", "four_stars", "four_stars", "five_stars", "four_stars", null, "three_stars", "four_stars", null, "five_stars", "three_stars", null, null, "three_stars", "four_stars", "four_stars", null, "four_stars", "three_stars", "five_stars", "four_stars", "five_stars", "four_stars", "five_stars", "four_stars", "four_stars", "four_stars", "four_stars", "four_stars", "four_stars", "four_stars", "four_stars", "five_stars", "five_stars", "three_stars", "five_stars", "four_stars", "four_stars", "five_stars", "four_stars", "four_stars", "two_stars", "five_stars", "five_stars", "five_stars", null, "four_stars", "five_stars", "four_stars", "five_stars", "five_stars", "four_stars", "three_stars", "four_stars", "four_stars", "four_stars", "four_stars", "four_stars", "two_stars", "five_stars", "five_stars", "four_stars", null, "four_stars", "four_stars", "four_stars", "two_stars", null, "four_stars", "four_stars", "four_stars", "four_stars", "four_stars", "four_stars", "four_stars", "four_stars", "four_stars", "three_stars", "five_stars", "four_stars", "four_stars", "three_stars", "four_stars", "three_stars", "four_stars", "four_stars", "four_stars", "four_stars", "five_stars", "four_stars", "five_stars", "two_stars", "three_stars", "four_stars", "four_stars", "four_stars", "four_stars", "four_stars", "four_stars", "four_stars", "four_stars", "four_stars", "four_stars", "five_stars", "four_stars", "four_stars", "five_stars", "three_stars", "three_stars", null, "four_stars", "four_stars", "five_stars", "four_stars", "four_stars", "five_stars", "five_stars", "four_stars", "four_stars", "four_stars", "four_stars", "three_stars", "four_stars", "three_stars", "two_stars", "four_stars", "five_stars", "four_stars", "four_stars", "four_stars", "four_stars", "five_stars", "three_stars", "four_stars", "four_stars", "three_stars", "four_stars", "four_stars", "four_stars", "three_stars", "three_stars", "three_stars", "four_stars", "four_stars", "five_stars", "five_stars", "five_stars", "five_stars", "three_stars", "four_stars", "four_stars", "five_stars", "four_stars", "five_st ...

# %% [markdown]
# ## Heatmap shows correlation of rating, reviews, size, installs, price
# > The purpose of this visualization is to measure corrolation between columns, as you can see there's high correlation between reviews and installs. This correlation means that prove positive relation.

# %%
aex = plt.axes()
sns.heatmap(df_play_store_clean.corr(), annot = True, fmt='.1g', vmin=-1, vmax=1, center= 0)
aex.set_title('correlation of rating, reviews, size, installs, price')
# Out:
# Text(0.5, 1, 'correlation of rating, reviews, size, installs, price')

# %% [markdown]
# ## Scatter Bubble show the relationship between installs and reviews in free Apps

# %%
df_play_store_clean.iplot(kind='bubble', x="rating_category",y="installs",categories="type", size='reviews', xTitle='Rating Stars', yTitle='installs', title="Scatter show the relationship between installs and reviews in free Apps")
# Out:
# <div>
#
#
#             <div id="916f3258-4063-4f88-8883-936b9230eabf" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("916f3258-4063-4f88-8883-936b9230eabf")) {
#                     Plotly.newPlot(
#                         '916f3258-4063-4f88-8883-936b9230eabf',
#                         [{"marker": {"color": "rgba(255, 153, 51, 1.0)", "line": {"width": 1.3}, "opacity": 0.8, "size": [12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 15, 12, 12, 12, 13, 12, 12, 12, 12, 12, 12, 12, 12, 13, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 13, 12, 12, 12, 12, 13, 12, 12, 12, 12, 12, 12, 13, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 13, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 84, 100, 12, 24, 13, 17, 16, 26, 12, 15, 17, 12, 18, 12, 12, 12, 18, 12, 12, 12, 12, 15, 12, 12, 12, 12, 12, 12, 15, 12, 18, 16, 12, 12, 13, 16, 14, 12, 12, 12, 12, 12, 12, 34, 12, 12, 12, 12, 12, 12, 25, 15, 12, 12, 12, 12, 12, 12, 25, 12, 12, 28, 15, 12, 14, 12, 15, 12, 12, 12, 13, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 22, 12, 12, 12, 12, 12, 12, 12, 13, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 20, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 13, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 18, 12, 12, 12, 12, 12, 12, 12, 12, 12, 21, 18, 12, 12, 12, 12, 12, 12, 12, 14, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 14, 12, 12, 12, 14, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 13, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 13, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 13, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 13, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 13, 12, 12, 12, 12, 12, 12, 12, 12, 1 ...

# %% [markdown]
# > Once you're ready to finish your presentation, check your output by using
# nbconvert to export the notebook and set up a server for the slides. From the
# terminal or command line, use the following expression:
# > > `jupyter nbconvert <file_name>.ipynb --to slides --post serve --template output_toggle`
#
# > This should open a tab in your web browser where you can scroll through your
# presentation. Sub-slides can be accessed by pressing 'down' when viewing its parent
# slide. Make sure you remove all of the quote-formatted guide notes like this one
# before you finish your presentation!
